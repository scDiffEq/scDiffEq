# %% [markdown]
# ## Preprocess dataset
# Read and preprocess data. Reduce dimensionality of the dataset and plot.

# %%
# %load_ext nb_black

import scdiffeq as sdq

# %% [markdown]
# Read the inputs from the files provided at the GitHub repository:

# %%
data = sdq.study.Weinreb2020(path="/home/mvinyard/data/Weinreb2020/")
# Out:
# AnnData object with n_obs × n_vars = 130887 × 25289
#     obs: 'Time point', 'Population', 'Annotation', 'Well'
#     var: 'gene_id'
#     obsm: 'X_spring', 'X_clone'

# %% [markdown]
# Filter non-highly variable genes and cell-cycle correlated genes as well as perform some basic preprocessing and annotation of cells and clones.

# %%
data.preprocess()
# Out:
# 2515 variable genes identified
#
# Removing genes correlated with the expression of those provided...
#
#
# From 2515 genes, 18 genes were removed leaving 2497 genes.
#
# AnnData object with n_obs × n_vars = 130887 × 2497
#     obs: 'Time point', 'Population', 'Annotation', 'Well'
#     var: 'gene_id', 'highly_variable'
#     uns: 'highly_variable_genes_idx'
#     obsm: 'X_spring', 'X_clone'

# %% [markdown]
# Scale the normalized counts (features already filtered for highly-variable features only), then perform PCA on this counts matrix followed by UMAP on that 50-dimension PCA matrix.

# %%
data.dimension_reduction()
# Out:
#  Scaling adata.X and adding the layer: adata.layers['X_scaled']

# %%
data.write()

# %% [markdown]
# ---
